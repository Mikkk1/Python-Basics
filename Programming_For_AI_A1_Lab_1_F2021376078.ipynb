# %% [markdown]
# # **GETTING STARTED WITH PYTHON**

# %% [markdown]
# ### Variables and Comments:

# %%
var = 2 # Variable Assignment

# %%
x = 2
y = 3

# %%
z = x + y # Assigning the values that come from X = y to z
z

# %%
# Multiple values:

x, y, z = "Sarim ", "Zahid ", "Sidhu"
print(x)
print(y)
print(z)
# Out:
# Sarim
# Zahid
# Sidhu

# %%
print(x,y,z)
# Out:
# Sarim  Zahid  Sidhu

# %%
a = x+y+z
a
# Out:
# 'Sarim Zahid Sidhu'

# %%
def myfunc():
  a = "Sarim Zahid Saeed"
  print("My name is "+ a)

myfunc()
# Out:
# My name is Sarim Zahid Saeed

# %%
a  = "Sarim"

def myfunc():
  global a
  a = "Sarim Zahid Saeed"

myfunc()

print("My name is "+ a)
# Out:
# My name is Sarim Zahid Saeed

# %%
a.split(" ")
# Out:
# ['Nice']

# %% [markdown]
# # Data Types

# %%
x = str("Hello World")
x = int(20)
x = float(20.5)
x = complex(1j)
x = list(("apple", "banana", "cherry"))
x = tuple(("apple", "banana", "cherry"))
x = range(6)
x = dict(name="John", age=36)
x = set(("apple", "banana", "cherry"))
x = frozenset(("apple", "banana", "cherry"))
x = bool(5)
x = bytes(5)

# %% [markdown]
# # NUMBERS

# %%
1+1
# Out:
# 2

# %%
1*3
# Out:
# 3

# %%
1/2
# Out:
# 0.5

# %%
2 ** 4
#Raised to power
# Out:
# 16

# %%
4%2
# Out:
# 0

# %%
5%2
# Out:
# 1

# %%
(2+3)*(5+5)
#Arithmetic operations on numbers
# Out:
# 50

# %%
num = 1 + 2j
type(num)
# Out:
# complex

# %%
f = 1.5 + 4.9
type(f), f
# Out:
# (float, 6.4)

# %%
var = 2

# %%
x = 2
y = 3

# %%
z = x + y

# %%
z
# Out:
# 5

# %%
s = 12

# %%
print(s) #Printing the Value of a variable
# Out:
# 12

# %%
s
# Out:
# 12

# %%
import random

print(random.randrange(1,10))
# Out:
# 8

# %% [markdown]
# # TYPE CASTING:

# %%
type(s), s, float(s)
# Out:
# (int, 12, 12.0)

# %%
type(f), f, int(f)
# Out:
# (float, 6.4, 6)

# %%
st = '(2+3)*(5+5)'

# %%
type(st), st
# Out:
# (str, '(2+3)*(5+5)')
