# %% [markdown]
# # STRINGS

# %%
'Single quotes' # Printing Strings using single qoutes
# Out:
# 'Single quotes'

# %%
"Double quotes" # Printing Strings using double qoutes
# Out:
# 'Double quotes'

# %%
"Wrap a lot's of single quotes in double qoutes"
# Out:
# "Wrap a lot's of single quotes in double qoutes"

# %%
a = '''My name is,
Sarim Zahid Sidhu,
I am perseuing BSAI.'''

print(a)
# Out:
# My name is,
# Sarim Zahid Sidhu,
# I am perseuing BSAI.

# %% [markdown]
# # FORMAT

# %%
num  = 123456789
name = 'Sarim'
x = 'My name is {} and my Number is {}'.format(name,num)
x
#It will put the first variable of the function in first bracket and the other in @nd.
# Out:
# 'My name is Sarim and my Number is 123456789'

# %%
type(x)
# Out:
# str

# %% [markdown]
# # MODIFY:

# %%
s = ' hello world '

# %%
s.capitalize() # It capitalizes the first letter
# Out:
# ' hello world '

# %%
s.upper() # It capitalizes the string
# Out:
# ' HELLO WORLD '

# %%
s.lower() # It writes the string in the lower case letters
# Out:
# ' hello world '

# %%
s.strip()
# Out:
# 'hello world'

# %%
s.replace('h','f')
# Out:
# ' fello world '

# %%
s.split(' ')
# Out:
# ['', 'hello', 'world', '']

# %% [markdown]
# # CONCAT:

# %%
s = 'Hello'
a = 'Sarim'
z = s + a

# %%
s.count('o') # It will count the given alphabet in the string
# Out:
# 2

# %%
s.isalnum() #
# Out:
# False

# %%
s.isalnum() #
# Out:
# False

# %%
multiline =  """hello
m
ert
l
e"""
print(multiline) # it will be used to print multiple line String As it is
# Out:
# hello
# m
# ert
# l
# e

# %%
multiline = "this is a \
multiline string."
multiline
# it will be used to print multiple line String Together
# Out:
# 'this is a multiline string.'

# %% [markdown]
# # SLICING:

# %%
s = 'Hello'
s[0]
# It will print the the first element of the string
# Out:
# 'H'

# %%
s[0:4]
# It will print the elements at the specified indexes
# Out:
# 'Hell'

# %%
s[:]
#It will  print the whole string
# Out:
# 'Hello'

# %%
s[:-1] # It will print except the last one element
# Out:
# 'Hell'

# %%
s[-3:]  # It will print except the first 3 elements
# Out:
# 'llo'

# %%
s = "This is a course on Artificial Intelligence"
s.split(" ") # Splits the string from spaces
# Out:
# ['This', 'is', 'a', 'course', 'on', 'Artificial', 'Intelligence']

# %%
s.split("Artificial")
#It will remove the specified word from the string
# Out:
# ['This is a course on ', ' Intelligence']

# %%
s.partition("Artificial")
#It will add the specified word that was removed from the string
# Out:
# ('This is a course on ', 'Artificial', ' Intelligence')

# %%
course_name = "Artificial Intelligence"
Duration = 16
s = f"This is a course on {course_name} and its duration is {Duration} weeks"
s
# It will put the values assigned tto the variable that are written in brackets.
# Out:
# 'This is a course on Artificial Intelligence and its duration is 16 weeks'

# %%
print("course" in s)
print("k" in s)
# Check if present in the string
# Out:
# True
# True

# %%
a = "Hello World"
print([a[1]])
# Out:
# ['e']

# %%
for x in a:
  print(x)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
print(len(a))
# Out:
# 11

# %%
txt = "the best thing in life are free"
print("free" in txt)
# Out:
# True

# %%
b = "Hellow World"
print(b[2:5])
# Out:
# llo

# %%
print(b[:5]) #print from starting till given index
# Out:
# Hello

# %%
print(b[2:]) #print from given index till end
# Out:
# llow World

# %%
print(b[-5:-2]) #print from specific range
# Out:
# Wor

# %% [markdown]
# # String Methods:

# %%
print(a.upper()) #Uppercase all character of string
# Out:
# HELLO WORLD

# %%
print(a.lower()) #Lowercase all character of string
# Out:
# hello world

# %%
print(a.strip())
# Out:
# Hello World

# %%
print(a.replace("H","J")) #Replaces H with J
# Out:
# Jello World

# %%
print(a.split()) #returns list of each word in string
# Out:
# ['Hello', 'World']

# %%
age = " 20"
txt = "My name is Sarim, I am" + age
print(txt)
# Out:
# My name is Sarim, I am 20

# %%
print(txt.format(age))
# Out:
# My name is Sarim, I am 20

# %%
quantity = 3
itemno = 567
price = 49.95
myorder = "I want {} pieces of item {} for {} dollars."
print(myorder.format(quantity, itemno, price))
# Out:
# I want 3 pieces of item 567 for 49.95 dollars.

# %%
txt = "We are the so-called \"Vikings\" from the north."
txt
# Out:
# 'We are the so-called "Vikings" from the north.'

# %%
x ="sarim zahid saeed"
x.capitalize()
# Out:
# 'Sarim zahid saeed'

# %%
x.casefold()
# Out:
# 'sarim zahid saeed'

# %%
x.count('s')
# Out:
# 2

# %%
n = x.center(50)
n
# Out:
# '                sarim zahid saeed                 '

# %%
x.encode()
# Out:
# b'sarim zahid saeed'

# %%
x.endswith("d")
# Out:
# True

# %%
y= "He\taskjndad\tallo"
z = y.expandtabs(2)
print(z)
# Out:
# He  askjndad  allo

# %%
x.find("e")
# Out:
# 14

# %%
n = "My {} is {}"
print(n.format("name","Sarim"))
# Out:
# My name is Sarim

# %%
x.index("e")
# Out:
# 14

# %%
x.isalpha()
# Out:
# False

# %%
x.isnumeric()
# Out:
# False

# %%
x.isdigit()
# Out:
# False

# %%
x.isdecimal()
# Out:
# False

# %%
x.isidentifier()
# Out:
# False

# %%
x.islower()
# Out:
# True

# %%
x.isprintable()
# Out:
# True

# %%
x.isspace()
# Out:
# (False, False)

# %%
x.istitle()
# Out:
# False

# %%
myTuple = ("Sarim", "Zahid", "Saeed")

s = "#".join(myTuple)
s
# Out:
# 'Sarim#Zahid#Saeed'

# %%
txt = "banana"

y = txt.ljust(20)

print(x, "is my favorite guy.")
# Out:
# sarim zahid saeed is my favorite guy.

# %%
print(x.lstrip())
# Out:
# sarim zahid saeed

# %%
x.strip()
# Out:
# 'sarim zahid saeed'

# %%
x = 'sarim zahid saeed'
mytable = str.maketrans("s","z")
print(x.translate(mytable))
# Out:
# zarim zahid zaeed

# %%
x.partition('zahid')
# Out:
# ('sarim ', 'zahid', ' saeed')

# %%
x.rfind('e')
# Out:
# 15

# %%
x.rjust(20)
# Out:
# '   sarim zahid saeed'

# %%
x.split(" ")
# Out:
# ['sarim', 'zahid', 'saeed']

# %%
a.splitlines()
# Out:
# ['My name is,', 'Sarim Zahid Sidhu,', 'I am perseuing BSAI.']

# %%
a.swapcase()
# Out:
# 'mY NAME IS,\nsARIM zAHID sIDHU,\ni AM PERSEUING bsai.'

# %%
x.zfill(50)
# Out:
# '000000000000000000000000000000000sarim zahid saeed'
