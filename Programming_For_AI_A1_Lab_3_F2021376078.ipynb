# %% [markdown]
# # BOOLEANS

# %%
#Boolean Operators
a = 5
b = 10
print(a == b)
print(a >= b)
print(a <= b)
print(a != b)
# Out:
# False
# False
# True
# True

# %%
bool("abc")
bool(123)
# Out:
# True

# %%
bool(())
# Out:
# False

# %%
bool("")
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
x = 123
print(isinstance(x,int))
# Out:
# True

# %%
bool(()), bool({}), bool(False), bool(0)
# Out:
# (False, False, False, False)

# %% [markdown]
# # Operators

# %%
# Assignment operators:
a = 2
b = 3.5
c = "Sarim Zahid Sidhu"

# %%
# Logical Operators:

input("Enter the value of X: ", x)
if x > 10 and x < 15:
  print("True")

# %%
input("Enter the value of X: ", x)
if not(x > 10 and x < 15):
  print("False")

# %%
# Comparison operators:
x = 5
y = 6

print(x == y)
print(x < y)
print(x > y)
print(x != y)
# Out:
# False
# True
# False
# True

# %%
# Arithmetic Operators
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a % b)
print(b ** a)
# Out:
# 5.5
# -1.5
# 7.0
# 0.5714285714285714
# 2.0
# 12.25

# %% [markdown]
# # LIST

# %%
my_list = [1,2,3]
my_list
# Out:
# [1, 2, 3]

# %%
my_list.append(3)
my_list
# Out:
# [1, 2, 3, 3]

# %%
len(my_list)
# Out:
# 4

# %%
my_list.append('D')
my_list.append(True)
my_list
# Out:
# [1, 2, 3, 3, 'D', True]

# %%
my_list[4]
# Out:
# 'D'

# %%
my_list[1:]
# Out:
# [2, 3, 3, 'D', True]

# %%
my_list[0] = 'NEW'
my_list
# Out:
# ['NEW', 2, 3, 3, 'D', True]

# %%
my_list[2:4] = ["Sarim"]
my_list
# Out:
# ['NEW', 2, 'Sarim', 'D', True]

# %%
my_list.insert(3, "Zahid")
my_list
# Out:
# ['NEW', 2, 'Sarim', 'Zahid', 'D', True]

# %%
tup = ("Kiwi", "Orange")
my_list.extend(tup)
my_list.extend(tup)
my_list
# Out:
# ['NEW', 2, 'Sarim', 'Zahid', 'D', True, 'Kiwi', 'Orange', 'Kiwi', 'Orange']

# %%
my_list.remove("Kiwi")
my_list.remove("Orange")
my_list
# Out:
# ['NEW', 2, 'Sarim', 'Zahid', 'D', True, 'Kiwi', 'Orange']

# %%
del my_list[-1]
my_list
# Out:
# ['NEW', 2, 'Sarim', 'Zahid', 'D', True, 'Kiwi']

# %%
for i in my_list:
  print(i)
# Out:
# NEW
# 2
# Sarim
# Zahid
# D
# True
# Kiwi

# %% [markdown]
# # List Comprehension:

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
new_list = [x for x in my_list if x != "Kiwi"]
new_list
# Out:
# ['NEW', 2, 'Sarim', 'Zahid', 'D', True]

# %%
nest = [1,2,3,[4,5,['target']]]
# Nest is the combination of lists

# %%
nlist = [54,86,74,95,2,0,45]
nlist.sort()
nlist
# Out:
# [0, 2, 45, 54, 74, 86, 95]

# %%
#Copy List By list Constructor
l1 = list(my_list)
l1
# Out:
# ['NEW', 2, 'Sarim', 'Zahid', 'D', True, 'Kiwi']

# %% [markdown]
# # Sort List:

# %%
nlist = [54,86,74,95,2,0,45]
nlist.sort(reverse = True)
nlist
# Out:
# [95, 86, 74, 54, 45, 2, 0]

# %% [markdown]
# ---

# %%
l_o_l = [[1,2,3],[3,4,5],[6,7,8]]
l_o_l
# list of lists
# Out:
# [[1, 2, 3], [3, 4, 5], [6, 7, 8]]

# %%
len(l_o_l)
# Number of lists in the list
# Out:
# 3

# %%
l_o_l.pop() #Removes the last list from the list
l_o_l
# Out:
# [[1, 2, 3], [3, 4, 5]]

# %%
len(l_o_l)
# Number of lists in the list
# Out:
# 2

# %%
my_list = ['abc' , 23]
my_list.count(23)
# Check how many times this comes in the list
# Out:
# 1

# %%
list_1 = [1,2,3,4,5]
list_2 = [5,6,7,8,9]
list_1+list_2
# Combining the lists
# Out:
# [1, 2, 3, 4, 5, 5, 6, 7, 8, 9]

# %% [markdown]
# # TUPLES

# %%
# Tuples
t = (1,2,3)

# %%
t[0]
# value at given index
# Out:
# 1

# %%
t[1:]
# values except the given index
# Out:
# (2, 3)

# %%
t[0] = 'NEW'
# We can not update the values of the tuples

# %%
t = (1,2,3)
u = (3,5,6)
v = t + u
print(v)
# combining and printing tuples
# Out:
# (1, 2, 3, 3, 5, 6)

# %% [markdown]
# # SETS

# %%
#SETS
st = {1,2,3}

# %%
# Does not allow duplicates
{1,2,3,1,2,1,2,3,3,3,3,2,2,2,1,1,2}
# Out:
# {1, 2, 3}

# %%
st.add(9)

# %%
s1 = {1,2,3}
s2 = {3,4,5}
intersection = s1.intersection(s2)
print("Intersection is:", intersection)
union = s1.union(s2)
print("Union is:", union)
difference = s1.difference(s2 )
print("Difference is:", difference)
# Functions to find tyhe unionm intersection and the difference between two sets
# Out:
# Intersection is: {3}
# Union is: {1, 2, 3, 4, 5}
# Difference is: {1, 2}

# %%
a = {1,3,4,6,'g'}
b = {2,3,4,5}
print("Intersection: ", a & b)
print("Union: ", a | b)
# Alterrnate syntax
# Out:
# Intersection:  {3, 4}
# Union:  {1, 2, 3, 4, 5, 6, 'g'}

# %% [markdown]
# # DICTIONARIES

# %%
#Dictionaries
d = {'key1':'item1','key2':'item2'}
d
# Out:
# {'key1': 'item1', 'key2': 'item2'}

# %%
d['key1']
d['key1'] = 5
d
# Out:
# {'key1': 5, 'key2': 'item2'}

# %%
d = {'k1':{'innerkey':[1,2,3]}}
print(d['k1'])
print(d['k1']['innerkey'])
# Out:
# {'innerkey': [1, 2, 3]}
# [1, 2, 3]

# %%
d['k1']['innerkey'][1]
# Out:
# 2

# %%
pets = {'dogs':5, 'cats' :4}
# Creates a Dictionary

# %%
pets.keys()
# gives the keys from the pets dictionary
# Out:
# dict_keys(['dogs', 'cats'])

# %%
pets.items()
# gives the items from the pets dictionary
# Out:
# dict_items([('dogs', 5), ('cats', 4)])

# %%
pets.values()
# gives the values from the pets dictionary
# Out:
# dict_values([5, 4])

# %%
"cats" in pets.keys()
#Checks the given word in the pets dictionary
# Out:
# True

# %%
pets.clear()
# Clears the dictionary
pets
# Out:
# {}

# %%
"cats" in pets.keys()
#Checks the given word in the pets dictionary
# Out:
# False
